# %% [markdown]
# # Unemployment Analysis during Covid 19

# %%
import numpy as np  
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt  
import plotly.express as pex
data = pd.read_csv("https://raw.githubusercontent.com/AritraPal13/Covid-19-Unemployment-Analysis/main/CovidUnemployment.csv")
data
# Out:
#              States         Date  Estimated Unemployment Rate   \
# 0    Andhra Pradesh   31-01-2020                          5.48
# 1    Andhra Pradesh   29-02-2020                          5.83
# 2    Andhra Pradesh   31-03-2020                          5.79
# 3    Andhra Pradesh   30-04-2020                         20.51
# 4    Andhra Pradesh   31-05-2020                         17.43
# ..              ...          ...                           ...
# 262     West Bengal   30-06-2020                          7.29
# 263     West Bengal   31-07-2020                          6.83
# 264     West Bengal   31-08-2020                         14.87
# 265     West Bengal   30-09-2020                          9.35
# 266     West Bengal   31-10-2020                          9.98
#
#      Estimated Employed  Estimated Labour Participation Rate  Region  \
# 0              16635535                                 41.02  South
# ...

# %%
data.describe(include="all")
# Out:
#                 States         Date  Estimated Unemployment Rate   \
# count              267          267                    267.000000
# unique              27           10                           NaN
# top     Andhra Pradesh   31-03-2020                           NaN
# freq                10           27                           NaN
# mean               NaN          NaN                     12.236929
# std                NaN          NaN                     10.803283
# min                NaN          NaN                      0.500000
# 25%                NaN          NaN                      4.845000
# 50%                NaN          NaN                      9.650000
# 75%                NaN          NaN                     16.755000
# max                NaN          NaN                     75.850000
#
#         Estimated Employed  Estimated Labour Participation Rate  Region  \
# count         2.670000e+02                            267.000000    267
# ...

# %%
data.mean()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16240\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Estimated Unemployment Rate             1.223693e+01
# Estimated Employed                      1.396211e+07
# Estimated Labour Participation Rate     4.168157e+01
# longitude                               2.282605e+01
# latitude                                8.053242e+01
# dtype: float64

# %%
h1= data.isnull().sum()           #Using isnull() to select all rows with NaN under a single DataFrame column:
h1
# Out:
# States                                  0
# Date                                    0
# Estimated Unemployment Rate             0
# Estimated Employed                      0
# Estimated Labour Participation Rate     0
# Region                                  0
# longitude                               0
# latitude                                0
# dtype: int64

# %%
data.columns= ["States","Date","Estimated Unemployment Rate","Estimated Employed", "Estimated Labour Participation Rate","Region","longitude","latitude"]

# %% [markdown]
# ## Analysis 1:

# %%
plt.figure(figsize=(15,10))
sns.histplot(x="Estimated Unemployment Rate",hue="Region",data=data).set(title="Unemployment rate according to Region")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.displot(data, x="Estimated Unemployment Rate",hue="Region", kind="kde",height=8).set(title="Unemployment Rate according to Region")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Analysis 2:

# %%
plt.figure(figsize=(15,10))
sns.histplot(x="Estimated Employed",hue="Region",data=data).set(title="Estimated No of Employee according to Region")
plt.grid(True)
plt.show()

# %%
sns.displot(data, x="Estimated Employed",hue="Region", kind="kde",height=8).set(title="Estimated No of Employee according to Regions")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Conclusion

# %% [markdown]
# I have used a "covidunemployment" dataset where I have analyze the unemployment rate ,employment rate and number of employyes employed in differenet regions and states of India and aslo visualized them through different plottings.
#
# Uttar Pradesh State recruited highest number of employees which is almost 555,247,990.
#
# Sikkim state recruited lowest number of employees which is almost 1,876,186.
#
# North region states has the highest unemployment rate.
#
# West region has the lowest unemployment rate.
#
# Haryana State has the highest unemployment rate i.e 274.77.
#
# Meghalaya State has the lowest unemployment rate in the country i.e 38.66.
